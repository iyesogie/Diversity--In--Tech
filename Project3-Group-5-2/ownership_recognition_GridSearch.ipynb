# %%
import numpy as np
import pandas as pd
diversity = pd.read_csv('ml_csv.csv')
diversity.head()
# Out:
#                       company ownership  year   valuations eeo_1 status  \
# 0                      NetApp    public  2016  11000000000          YES
# 1                        Lyft   private  2016   8000000000          YES
# 2                  Salesforce    public  2016  58000000000          YES
# 3  Hewlett Packard Enterprise    public  2016  39000000000          YES
# 4                 Sanmina-SCI    public  2016   3000000000          YES
#
#    sum(female)  sum(male)  sum(American_Indian_Alaskan_Native)  sum(Asian)  \
# 0         4522      14379                                   67        5184
# 1         1431       1970                                   18         657
# 2        13189      28212                                   53       10000
# 3        34390      69588                                  412       13268
# 4         6280       9745                                   58        4021
#
#    sum(Black_or_African_American)  ...  sum(Administrative support)  \
# 0                             633  ...                          182
# 1                             206  ...                          836
# 2                             968  ...                          830
# 3                            7468  ...                         5840
# 4                             944  ...                         1362
#
#    sum(Craft workers)  sum(Executives)  sum(Managers)  sum(Professionals)  \
# 0                   0               72           2006                7764
# 1                   0               30            518                1366
# 2                   0              474           5204               16238
# 3                   0             1198          11880               68246
# 4                 322              244           1182                2264
#
#    sum(Sales workers)  sum(Service workers)  sum(Technicians)  \
# 0                1302                     0                36
# 1                 112                     4                 0
# 2                6686                     0                 0
# 3                8958                     0              7354
# 4                 178                   114              1416
#
#    sum(laborers and helpers)  sum(operatives)
# 0                          0                0
# 1                          0                0
# 2                          0                0
# 3                        366              136
# 4                          8             3320
#
# [5 rows x 25 columns]

# %%
#drop unimportant columns
diversity_without_year=diversity.drop("year",axis=1)
diversity_without_eeo=diversity_without_year.drop("eeo_1 status",axis=1)
diversity_without_company=diversity_without_eeo.drop("company",axis=1)
diversity_without_company.head()
# Out:
#   ownership   valuations  sum(female)  sum(male)  \
# 0    public  11000000000         4522      14379
# 1   private   8000000000         1431       1970
# 2    public  58000000000        13189      28212
# 3    public  39000000000        34390      69588
# 4    public   3000000000         6280       9745
#
#    sum(American_Indian_Alaskan_Native)  sum(Asian)  \
# 0                                   67        5184
# 1                                   18         657
# 2                                   53       10000
# 3                                  412       13268
# 4                                   58        4021
#
#    sum(Black_or_African_American)  sum(Hispanic_or_Latino)  \
# 0                             633                      774
# 1                             206                      241
# 2                             968                     1656
# 3                            7468                     5974
# 4                             944                     1825
#
#    sum(Native_Hawaiian_or_Pacific_Islander)  sum(Overall_totals)  ...  \
# 0                                        26                18901  ...
# 1                                         9                 3401  ...
# 2                                       160                41401  ...
# 3                                       160               103978  ...
# 4                                        34                16025  ...
#
#    sum(Administrative support)  sum(Craft workers)  sum(Executives)  \
# 0                          182                   0               72
# 1                          836                   0               30
# 2                          830                   0              474
# 3                         5840                   0             1198
# 4                         1362                 322              244
#
#    sum(Managers)  sum(Professionals)  sum(Sales workers)  \
# 0           2006                7764                1302
# 1            518                1366                 112
# 2           5204               16238                6686
# 3          11880               68246                8958
# 4           1182                2264                 178
#
#    sum(Service workers)  sum(Technicians)  sum(laborers and helpers)  \
# 0                     0                36                          0
# 1                     4                 0                          0
# 2                     0                 0                          0
# 3                     0              7354                        366
# 4                   114              1416                          8
#
#    sum(operatives)
# 0                0
# 1                0
# 2                0
# 3              136
# 4             3320
#
# [5 rows x 22 columns]

# %%
#split data into X and y
X = diversity_without_company.drop("ownership", axis=1)
y = diversity_without_company["ownership"]
print(X.shape, y.shape)
# Out:
# (25, 21) (25,)

# %%
# Split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
print(X_train.shape,y_train.shape)
# Out:
# (18, 21) (18,)

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
X_scaler=MinMaxScaler().fit(X_train)
X_train_scaled=X_scaler.transform(X_train)
X_test_scaled=X_scaler.transform(X_test)

# %%
# Create the SVC Model
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled,y_train)
print(model.score(X_train_scaled,y_train))
print(model.score(X_test_scaled,y_test))
# Out:
# 0.7777777777777778
# 0.7142857142857143

# %%
SVC(C=1.0,cache_size=200,class_weight=None,coef0=0.0,decision_function_shape=None,degree=3,gamma="auto",kernel="linear",max_iter=-1,probability=False,random_state=None,shrinking=True,tol=0.001,verbose=False)
# Out:
# SVC(decision_function_shape=None, gamma='auto', kernel='linear')

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.5,1, 5, 10],
              'gamma': [0.00005,0.0001,0.0005, 0.001]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ................C=0.5, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=5e-05;, score=0.667 total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=5e-05;, score=1.000 total time=   0.0s
# [CV 1/5] END ...............C=0.5, gamma=0.0001;, score=0.750 total time=   0.0s
# [CV 2/5] END ...............C=0.5, gamma=0.0001;, score=0.750 total time=   0.0s
# [CV 3/5] END ...............C=0.5, gamma=0.0001;, score=0.750 total time=   0.0s
# [CV 4/5] END ...............C=0.5, gamma=0.0001;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............C=0.5, gamma=0.0001;, score=1.000 total time=   0.0s
# [CV 1/5] END ...............C=0.5, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 2/5] END ...............C=0.5, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 3/5] END ...............C=0.5, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 4/5] END ...............C=0.5, gamma=0.0005;, score=0.667 total time=   0.0s
# [CV 5/5] END ...............C=0.5, gamma=0.0005;, score=1.000 total time=   0.0s
# [CV 1/5] END ................C=0.5, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 2/5] END ................C=0.5, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 3/5] END ................C=0.5, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 4/5] END ................C=0.5, gamma=0.001;, score=0.667 total time=   0.0s
# [CV 5/5] END ................C=0.5, gamma=0.001;, score=1.000 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=5e-05;, score=0.667 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=5e-05;, score=1.000 total time=   0.0s
# [CV 1/5] END .................C=1, gamma=0.0001;, score=0.750 total time=   0.0s
# [CV 2/5] END .................C=1, gamma=0.0001;, score=0.750 total time=   0.0s
# D:\Jane\anaconda\envs\pythonadv\lib\site-packages\sklearn\model_selection\_split.py:668: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [CV 3/5] END .................C=1, gamma=0.0001;, score=0.750 total time=   0.0s
# [CV 4/5] END .................C=1, gamma=0.0001;, score=0.667 total time=   0.0s
# [CV 5/5] END .................C=1, gamma=0.0001;, score=1.000 total time=   0.0s
# [CV 1/5] END .................C=1, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 2/5] END .................C=1, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 3/5] END .................C=1, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 4/5] END .................C=1, gamma=0.0005;, score=0.667 total time=   0.0s
# [CV 5/5] END .................C=1, gamma=0.0005;, score=1.000 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.667 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=1.000 total time=   0.0s
# [CV 1/5] END ..................C=5, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 2/5] END ..................C=5, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 3/5] END ..................C=5, gamma=5e-05;, score=0.500 total time=   0.0s
# [CV 4/5] END ..................C=5, gamma=5e-05;, score=0.667 total time=   0.0s
# [CV 5/5] END ..................C=5, gamma=5e-05;, score=0.667 total time=   0.0s
# [CV 1/5] END .................C=5, gamma=0.0001;, score=0.750 total time=   0.0s
# [CV 2/5] END .................C=5, gamma=0.0001;, score=0.750 total time=   0.0s
# [CV 3/5] END .................C=5, gamma=0.0001;, score=0.500 total time=   0.0s
# [CV 4/5] END .................C=5, gamma=0.0001;, score=0.667 total time=   0.0s
# [CV 5/5] END .................C=5, gamma=0.0001;, score=0.667 total time=   0.0s
# [CV 1/5] END .................C=5, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 2/5] END .................C=5, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 3/5] END .................C=5, gamma=0.0005;, score=0.500 total time=   0.0s
# [CV 4/5] END .................C=5, gamma=0.0005;, score=0.667 total time=   0.0s
# [CV 5/5] END .................C=5, gamma=0.0005;, score=0.667 total time=   0.0s
# [CV 1/5] END ..................C=5, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 2/5] END ..................C=5, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 3/5] END ..................C=5, gamma=0.001;, score=0.500 total time=   0.0s
# [CV 4/5] END ..................C=5, gamma=0.001;, score=0.667 total time=   0.0s
# [CV 5/5] END ..................C=5, gamma=0.001;, score=0.667 total time=   0.0s
# [CV 1/5] END .................C=10, gamma=5e-05;, score=0.750 total time=   0.0s
# [CV 2/5] END .................C=10, gamma=5e-05;, score=0.500 total time=   0.0s
# [CV 3/5] END .................C=10, gamma=5e-05;, score=0.500 total time=   0.0s
# [CV 4/5] END .................C=10, gamma=5e-05;, score=0.667 total time=   0.0s
# [CV 5/5] END .................C=10, gamma=5e-05;, score=0.667 total time=   0.0s
# [CV 1/5] END ................C=10, gamma=0.0001;, score=0.750 total time=   0.0s
# [CV 2/5] END ................C=10, gamma=0.0001;, score=0.500 total time=   0.0s
# [CV 3/5] END ................C=10, gamma=0.0001;, score=0.500 total time=   0.0s
# [CV 4/5] END ................C=10, gamma=0.0001;, score=0.667 total time=   0.0s
# [CV 5/5] END ................C=10, gamma=0.0001;, score=0.667 total time=   0.0s
# [CV 1/5] END ................C=10, gamma=0.0005;, score=0.750 total time=   0.0s
# [CV 2/5] END ................C=10, gamma=0.0005;, score=0.500 total time=   0.0s
# [CV 3/5] END ................C=10, gamma=0.0005;, score=0.500 total time=   0.0s
# [CV 4/5] END ................C=10, gamma=0.0005;, score=0.667 total time=   0.0s
# [CV 5/5] END ................C=10, gamma=0.0005;, score=0.667 total time=   0.0s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.750 total time=   0.0s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.500 total time=   0.0s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.500 total time=   0.0s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.667 total time=   0.0s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.667 total time=   0.0s
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [0.5, 1, 5, 10],
#                          'gamma': [5e-05, 0.0001, 0.0005, 0.001]},
#              verbose=3)

# %%
# List the best parameters for this dataset
print(grid.best_params_)
# Out:
# {'C': 0.5, 'gamma': 5e-05}

# %%
# List the best score
print(grid.best_score_)
# Out:
# 0.7833333333333333

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test_scaled)
predictions
# Out:
# array(['public', 'public', 'public', 'public', 'public', 'public',
#        'public'], dtype=object)

# %% [markdown]
# Source: [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
